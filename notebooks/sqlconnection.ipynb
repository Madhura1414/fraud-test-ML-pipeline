# %%
# import pandas as pd 
import mysql.connector as connection

# %%
# !pip install sqlachemy
# !pip install mysqlclient

# %%
mydb = connection.connect(host = 'localhost', user = 'root', password = 'root123', use_pure = True)

# %%
query = 'create database fraudtest;'
cursor = mydb.cursor()

# %%
cursor.execute(query)

# %%
mydb.close()

# %% [markdown]
# #### Upload a pandas dataframe into the database created

# %%
# from sqlalchemy import create_engine
import pandas as pd
df = pd.DataFrame(pd.read_csv(r"C:\Users\Bharath\Desktop\Maddy\third_eye\fraud test.csv"))

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      21/06/2020 12:14  2.291160e+15
# 1           1      21/06/2020 12:14  3.573030e+15
# 2           2      21/06/2020 12:14  3.598220e+15
# 3           3      21/06/2020 12:15  3.591920e+15
# 4           4      21/06/2020 12:15  3.526830e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
# sql alchemy 
from sqlalchemy import create_engine
# engine = create_engine(f"mysql://{user_name}:{password}@{"localhost"}/{"Database_name"}")
engine = create_engine(f'mysql://{"root"}:{"root123"}@{"localhost"}/{"fraudtest"}')

# %%
table_name = "projectdata"
try: 
    df.to_sql(name = table_name, con = engine, if_exists = 'append', index = False)
    print("Data entered successfully")
except Exception as e: 
    print(e)
# Out:
# Data entered successfully

# %% [markdown]
# #### Fetch data from a database

# %%
import pandas as pd
query = "SELECT * From projectdata"
df1 = pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Bharath\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File c:\Users\Bharath\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File c:\Users\Bharath\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      21/06/2020 12:14  2.291160e+15
# 1           1      21/06/2020 12:14  3.573030e+15
# 2           2      21/06/2020 12:14  3.598220e+15
# 3           3      21/06/2020 12:15  3.591920e+15
# 4           4      21/06/2020 12:15  3.526830e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                   float64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
from dataclasses import dataclass
import os
@dataclass

class ConnectDatabase:
    def establish_connection(self, host, user, password, database, tablename):
        self.engine = create_engine(f'mysql://{user}:{password}@{host}/{database}')
        self.tablename = tablename
        print("Table name:", self.tablename)
        print("engine:", self.engine)
        
        
    def retrieve_data(self): 
        data_path = os.path.join('../notebooks/data')
        print(data_path)
        # print("Table name:", self.tablename)
        query = f'SELECT * FROM {self.tablename}'
        # query = f'SELECT * FROM projectdata'
        print("SQL query:", query)
        df1 = pd.DataFrame(pd.read_sql(query, self.engine))
        df1.to_csv(os.path.join(data_path, 'file1.csv'), index=False, header=True)

# %%
obj = ConnectDatabase()
# obj.establish_connection('localhost','root','root123','fraudtest','projectdata')
# obj.retrieve_data()

# %%
obj.establish_connection('localhost','root','root123','fraudtest','projectdata')
# Out:
# Table name: projectdata
# engine: Engine(mysql://root:***@localhost/fraudtest)

# %%
obj.retrieve_data()
# Out:
# ../notebooks/data
# SQL query: SELECT * FROM projectdata

# %%
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0      21/06/2020 12:14  2.291160e+15
# 1                1      21/06/2020 12:14  3.573030e+15
# 2                2      21/06/2020 12:14  3.598220e+15
# 3                3      21/06/2020 12:15  3.591920e+15
# 4                4      21/06/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 555714      555714      31/12/2020 23:59  3.056060e+13
# 555715      555715      31/12/2020 23:59  3.556610e+15
# 555716      555716      31/12/2020 23:59  6.011720e+15
# 555717      555717      31/12/2020 23:59  4.079770e+12
# 555718      555718      31/12/2020 23:59  4.170690e+15
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
# class ConnectDB(): 
#     def __init__(self): 
#         None 
        
#     def establish_connection(self, host, user, password, database): 
#         self. ....
        
#     def retrieve_data():
